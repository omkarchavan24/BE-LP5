# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import accuracy_score, classification_report

# %%
columns = [
    'letter',
    'x-box',
    'y-box',
    'width',
    'high',
    'onpix',
    'x-bar',
    'y-bar',
    'x2bar',
    'y2bar',
    'xybar',
    'x2ybr',
    'xy2br',
    'x-ege',
    'xegvy',
    'y-ege',
    'yegvx'
]

df = pd.read_csv("letter-recognition.data",names=columns)

# %%
df.head()
# Out:
#   letter  x-box  y-box  width  high  onpix  x-bar  y-bar  x2bar  y2bar  xybar  \
# 0      T      2      8      3     5      1      8     13      0      6      6
# 1      I      5     12      3     7      2     10      5      5      4     13
# 2      D      4     11      6     8      6     10      6      2      6     10
# 3      N      7     11      6     6      3      5      9      4      6      4
# 4      G      2      1      3     1      1      8      6      6      6      6
#
#    x2ybr  xy2br  x-ege  xegvy  y-ege  yegvx
# 0     10      8      0      8      0      8
# 1      3      9      2      8      4     10
# 2      3      7      3      7      3      9
# 3      4     10      6     10      2      8
# 4      5      9      1      7      5     10

# %%
x = df.drop('letter',axis=1).values
y = df['letter'].values

# %%
# Label Encoding
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
# Split dataset: 80% training, 20% testing
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = Sequential()
model.add(Dense(64,activation='relu',input_shape=(16,)))
model.add(Dense(32,activation='relu'))
model.add(Dense(26,activation='softmax'))

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 64)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 26)                  │             858 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,026 (15.73 KB)
#  Trainable params: 4,026 (15.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=30,validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5181 - loss: 1.7920 - val_accuracy: 0.7308 - val_loss: 1.0138
# Epoch 2/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7627 - loss: 0.8477 - val_accuracy: 0.7975 - val_loss: 0.7351
# Epoch 3/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8081 - loss: 0.6627 - val_accuracy: 0.8335 - val_loss: 0.5949
# Epoch 4/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8366 - loss: 0.5557 - val_accuracy: 0.8500 - val_loss: 0.5237
# Epoch 5/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8592 - loss: 0.4833 - val_accuracy: 0.8635 - val_loss: 0.4698
# Epoch 6/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8716 - loss: 0.4323 - val_accuracy: 0.8767 - val_loss: 0.4265
# Epoch 7/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8861 - loss: 0.3887 - val_accuracy: 0.8895 - val_loss: 0.3868
# Epoch 8/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8918 - loss: 0.3567 - val_accuracy: 0.8940 - val_loss: 0.3650
# Epoch 9/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9018 - loss: 0.3302 - val_accuracy: 0.8913 - val_loss: 0.3495
# Epoch 10/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9079 - loss: 0.3048 - val_accuracy: 0.9060 - val_loss: 0.3163
# Epoch 11/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9146 - loss: 0.2834 - val_accuracy: 0.9030 - val_loss: 0.3074
# Epoch 12/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9186 - loss: 0.2666 - val_accuracy: 0.9107 - val_loss: 0.2874
# Epoch 13/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9214 - loss: 0.2517 - val_accuracy: 0.9140 - val_loss: 0.2751
# Epoch 14/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9268 - loss: 0.2372 - val_accuracy: 0.9185 - val_loss: 0.2667
# Epoch 15/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9306 - loss: 0.2253 - val_accuracy: 0.9222 - val_loss: 0.2585
# Epoch 16/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9342 - loss: 0.2133 - val_accuracy: 0.9200 - val_loss: 0.2510
# Epoch 17/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9355 - loss: 0.2037 - val_accuracy: 0.9197 - val_loss: 0.2551
# Epoch 18/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9384 - loss: 0.1945 - val_accuracy: 0.9235 - val_loss: 0.2404
# Epoch 19/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9415 - loss: 0.1863 - val_accuracy: 0.9273 - val_loss: 0.2294
# Epoch 20/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9431 - loss: 0.1788 - val_accuracy: 0.9258 - val_loss: 0.2240
# Epoch 21/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9472 - loss: 0.1711 - val_accuracy: 0.9298 - val_loss: 0.2213
# Epoch 22/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9480 - loss: 0.1641 - val_accuracy: 0.9298 - val_loss: 0.2215
# Epoch 23/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9482 - loss: 0.1580 - val_accuracy: 0.9308 - val_loss: 0.2142
# Epoch 24/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9509 - loss: 0.1540 - val_accuracy: 0.9300 - val_loss: 0.2174
# Epoch 25/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9524 - loss: 0.1482 - val_accuracy: 0.9345 - val_loss: 0.2056
# Epoch 26/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9542 - loss: 0.1425 - val_accuracy: 0.9333 - val_loss: 0.2077
# Epoch 27/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9536 - loss: 0.1389 - val_accuracy: 0.9335 - val_loss: 0.2027
# Epoch 28/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9570 - loss: 0.1325 - val_accuracy: 0.9352 - val_loss: 0.1983
# Epoch 29/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9583 - loss: 0.1279 - val_accuracy: 0.9367 - val_loss: 0.1958
# Epoch 30/30
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9606 - loss: 0.1251 - val_accuracy: 0.9377 - val_loss: 0.1944

# %%
loss,accuracy = model.evaluate(x_test,y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9377 - loss: 0.1944

# %%
print(accuracy)
# Out:
# 0.937749981880188

# %%
predictions = model.predict(x_test)

# Convert probabilities into class labels
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print("\nClassification Report:\n")

print(
    classification_report(
        y_test,
        predicted_classes
    )
)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       149
#            1       0.92      0.90      0.91       153
#            2       0.92      0.93      0.92       137
#            3       0.91      0.96      0.93       156
#            4       0.88      0.96      0.92       141
#            5       0.92      0.89      0.91       140
#            6       0.97      0.91      0.94       160
#            7       0.91      0.79      0.85       144
#            8       0.96      0.93      0.94       146
#            9       0.95      0.96      0.96       149
#           10       0.83      0.92      0.87       130
#           11       0.95      0.96      0.96       155
#           12       0.96      0.97      0.97       168
#           13       0.94      0.95      0.94       151
#           14       0.95      0.93      0.94       145
#           15       0.98      0.92      0.95       173
#           16       0.93      0.95      0.94       166
#           17       0.87      0.86      0.87       160
#           18       0.98      0.93      0.95       171
#           19       0.95      0.96      0.95       163
#           20       0.96      0.95      0.95       183
#           21       0.96      0.95      0.95       158
#           22       0.97      0.97      0.97       148
#           23       0.92      0.98      0.95       154
#           24       0.96      0.98      0.97       168
#           25       0.96      0.96      0.96       132
#
#     accuracy                           0.94      4000
#    macro avg       0.94      0.94      0.94      4000
# weighted avg       0.94      0.94      0.94      4000
